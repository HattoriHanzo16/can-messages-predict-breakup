# %% [markdown]
# # 04 - Machine Learning
#
# Train and compare Logistic Regression and Decision Tree classifiers.

# %%
import pandas as pd
from src.models import train_test_evaluate

df = pd.read_csv('data/processed/combined_cleaned.csv')
results = train_test_evaluate(df)
results

# %% [markdown]
# ## Interpretation
#
# Summarize which model performs better and why.
