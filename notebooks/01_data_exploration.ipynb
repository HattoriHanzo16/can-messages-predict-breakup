# %% [markdown]
# # 01 - Data Exploration
#
# Initial inspection of raw datasets and label distribution.

# %%
import pandas as pd
from src.data_processing import load_raw_data

df = load_raw_data(
    'data/raw/reddit_breakup_dataset_cleaned.csv',
    'data/raw/relationship_advice.csv'
)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from src.data_processing import load_raw_data
#       4 df = load_raw_data(
#       5     'data/raw/reddit_breakup_dataset_cleaned.csv',
#       6     'data/raw/relationship_advice.csv'
#       7 )
#       8 df.head()
#
# ModuleNotFoundError: No module named 'src'

# %%
df.shape

# %%
df['breakup'].value_counts()

# %%
df.isna().sum().sort_values(ascending=False)
