# %% [markdown]
# # 02 - Data Preprocessing
#
# Clean, standardize, and engineer features.

# %%
from src.data_processing import preprocess_pipeline

df = preprocess_pipeline(
    'data/raw/reddit_breakup_dataset_cleaned.csv',
    'data/raw/relationship_advice.csv'
)
df.head()

# %%
df.describe(include='all')

# %%
df.to_csv('data/processed/combined_cleaned.csv', index=False)
