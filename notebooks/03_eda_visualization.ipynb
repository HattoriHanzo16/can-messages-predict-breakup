# %% [markdown]
# # 03 - EDA and Visualization
#
# Required visualizations and statistical summaries.

# %%
import pandas as pd
from src.visualization import (
    plot_class_balance,
    plot_text_length_distribution,
    plot_word_count_distribution,
    plot_numeric_boxplots,
    plot_correlation_heatmap,
    plot_scatter_text_vs_comments,
)

df = pd.read_csv('data/processed/combined_cleaned.csv')
df.head()

# %%
df.describe()

# %%
plot_class_balance(df)

# %%
plot_text_length_distribution(df)

# %%
plot_word_count_distribution(df)

# %%
plot_numeric_boxplots(df)

# %%
plot_correlation_heatmap(df)

# %%
plot_scatter_text_vs_comments(df)
